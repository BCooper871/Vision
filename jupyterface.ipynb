# %%
import numpy as np
import cv2 as cv
import os

DIR = r'/home/ben/Documents/Courses/OpenCV/faces_train/train'

# %%
people = []
for i in os.listdir(DIR):
    people.append(i)

haar_cascade = cv.CascadeClassifier('haar_face.xml')

# %%
face_recognizer = cv.face.LBPHFaceRecognizer_create()    
face_recognizer.read('face_trained.yml')

img = cv.imread(r'/home/ben/Documents/Courses/OpenCV/faces_train/validate/tom/images3.jpeg')

# %%
gray = cv.cvtColor(img, cv.COLOR_BGR2GRAY)
#cv.imshow('person', gray)

#detect face

faces_rect = haar_cascade.detectMultiScale(gray, 1.1, 4)

for (x,y,w,h) in faces_rect:
    faces_roi = gray[y:y+h, x:x+w]
    
    label, confidence = face_recognizer.predict(faces_roi)
    print(f'Label is {people[label]} with confidence of {confidence}')
    
    cv.putText(img, str(people[label]), (10,20), cv.FONT_HERSHEY_PLAIN, 1.0,
    (0,255,0), thickness=1)
    cv.putText(img, str(f'{confidence:.1f} % confidence this is'), (10,10), cv.FONT_HERSHEY_PLAIN, 1.0,
    (0,255,0), thickness = 1)
    cv.rectangle(img, (x,y), (x+w,y+h), (0,255,0), thickness=2)
cv.imshow('Detected Face', img)

cv.waitKey(0)
# Out:
# Label is Tom Hardy with confidence of 94.69846048441691
# QObject::moveToThread: Current thread (0x556e899a09b0) is not the object's thread (0x556e895c3360).
# Cannot move to target thread (0x556e899a09b0)
#
# QObject::moveToThread: Current thread (0x556e899a09b0) is not the object's thread (0x556e895c3360).
# Cannot move to target thread (0x556e899a09b0)
#
# QObject::moveToThread: Current thread (0x556e899a09b0) is not the object's thread (0x556e895c3360).
# Cannot move to target thread (0x556e899a09b0)
#
# QObject::moveToThread: Current thread (0x556e899a09b0) is not the object's thread (0x556e895c3360).
# Cannot move to target thread (0x556e899a09b0)
#
# QObject::moveToThread: Current thread (0x556e899a09b0) is not the object's thread (0x556e895c3360).
# Cannot move to target thread (0x556e899a09b0)
#
# QObject::moveToThread: Current thread (0x556e899a09b0) is not the object's thread (0x556e895c3360).
# Cannot move to target thread (0x556e899a09b0)
#
# ...
